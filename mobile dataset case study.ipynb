# %%
# mobile dataset case study

# %%
#step 1 :
#understand the date and problem statement

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("mobile_dataset1.csv")

# %%
df.head()
# Out:
#   company_name  RAM  ROM                 type  height_in   display  \
# 0      SAMSUNG   12  512    Galaxy Z Fold4 5G        7.6  Full HD+
# 1      SAMSUNG   12  256    Galaxy Z Fold3 5G        7.6     QXGA+
# 2      SAMSUNG   12  256    Galaxy Z Fold4 5G        7.6  Full HD+
# 3      SAMSUNG   12  256    Galaxy Z Fold3 5G        7.6     QXGA+
# 4      SAMSUNG   12  512  Galaxy S22 Ultra 5G        6.8  Quad HD+
#
#    battery_power  front_camera back_camera  height_cm  \
# 0           4400          10.0          72     19.304
# 1           4400          10.0          36     19.304
# 2           4400          10.0          72     19.304
# 3           4400          10.0          36     19.304
# 4           5000          40.0         130     17.272
#
#                            processor      price
# 0       Qualcomm Snapdragon 8+ Gen 1  ₹1,64,999
# 1  Qualcomm Snapdragon 888 Octa-Core  ₹1,61,000
# 2       Qualcomm Snapdragon 8+ Gen 1  ₹1,54,999
# ...

# %%
df.tail()
# Out:
#     company_name  RAM  ROM            type  height_in   display  \
# 791        Redmi    4   64      Note 7 Pro       6.30  Full HD+
# 792        Redmi    4   64      Note 7 Pro       6.30  Full HD+
# 793        Redmi    4   64      Note 7 Pro       6.30  Full HD+
# 794      Infinix    8  128  Note 12 Pro 5G       6.70  Full HD+
# 795        REDMI    4   64     11 Prime 5G       6.58    Normal
#
#      battery_power  front_camera back_camera  height_cm  \
# 791           4000          13.0          53    16.0020
# 792           4000          13.0          53    16.0020
# 793           4000          13.0          53    16.0020
# 794           5000          16.0         112    17.0180
# 795           5000          50.0          50    16.7132
#
#                      processor    price
# 791    Qualcomm Snapdragon 675  ₹15,999
# 792    Qualcomm Snapdragon 675  ₹15,999
# 793    Qualcomm Snapdragon 675  ₹15,999
# 794  Mediatek Dimensity 810 5G  ₹15,999
# ...

# %%
df.shape
# Out:
# (796, 12)

# %%
df.columns
# Out:
# Index(['company_name', 'RAM', 'ROM', 'type', 'height_in', 'display',
#        'battery_power', 'front_camera', 'back_camera', 'height_cm',
#        'processor', 'price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# company_name      object
# RAM                int64
# ROM                int64
# type              object
# height_in        float64
# display           object
# battery_power      int64
# front_camera     float64
# back_camera       object
# height_cm        float64
# processor         object
# price             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 796 entries, 0 to 795
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   company_name   796 non-null    object
#  1   RAM            796 non-null    int64
#  2   ROM            796 non-null    int64
#  3   type           796 non-null    object
#  4   height_in      796 non-null    float64
#  5   display        796 non-null    object
#  6   battery_power  796 non-null    int64
#  7   front_camera   795 non-null    float64
#  8   back_camera    795 non-null    object
#  9   height_cm      789 non-null    float64
#  10  processor      635 non-null    object
#  11  price          796 non-null    object
# dtypes: float64(3), int64(3), object(6)
# memory usage: 74.8+ KB

# %%
# we are in the step of cleaning the data

# how can we check missing values 

df.isnull().sum()
# Out:
# company_name       0
# RAM                0
# ROM                0
# type               0
# height_in          0
# display            0
# battery_power      0
# front_camera       1
# back_camera        1
# height_cm          7
# processor        161
# price              0
# dtype: int64

# %%
# to check duplicate values

df.drop_duplicates(inplace = True)

# %%
df.drop_duplicates()
# Out:
#     company_name  RAM  ROM                 type  height_in   display  \
# 0        SAMSUNG   12  512    Galaxy Z Fold4 5G       7.60  Full HD+
# 1        SAMSUNG   12  256    Galaxy Z Fold3 5G       7.60     QXGA+
# 2        SAMSUNG   12  256    Galaxy Z Fold4 5G       7.60  Full HD+
# 3        SAMSUNG   12  256    Galaxy Z Fold3 5G       7.60     QXGA+
# 4        SAMSUNG   12  512  Galaxy S22 Ultra 5G       6.80  Quad HD+
# ..           ...  ...  ...                  ...        ...       ...
# 789      SAMSUNG    6  128           Galaxy A13       6.60  Full HD+
# 790        Nokia    3   16                    5       5.20    Normal
# 791        Redmi    4   64           Note 7 Pro       6.30  Full HD+
# 794      Infinix    8  128       Note 12 Pro 5G       6.70  Full HD+
# 795        REDMI    4   64          11 Prime 5G       6.58    Normal
#
#      battery_power  front_camera back_camera  height_cm  \
# 0             4400          10.0          72    19.3040
# ...

# %%
df.shape
# Out:
# (538, 12)

# %%
df.head(1)
# Out:
#   company_name  RAM  ROM               type  height_in   display  \
# 0      SAMSUNG   12  512  Galaxy Z Fold4 5G        7.6  Full HD+
#
#    battery_power  front_camera back_camera  height_cm  \
# 0           4400          10.0          72     19.304
#
#                       processor      price
# 0  Qualcomm Snapdragon 8+ Gen 1  ₹1,64,999

# %%
# to delete the column 

# del df["height-in"] - FYI

# %%
# wrte a loop to get nunique values for all the coloumns in the dataset

for i in df.columns:
    print(i,"-",df[i].nunique())
# Out:
# company_name - 28
# RAM - 6
# ROM - 6
# type - 273
# height_in - 48
# display - 4
# battery_power - 49
# front_camera - 27
# back_camera - 66
# height_cm - 47
# processor - 147
# price - 248

# %%
df.head(9)
# Out:
#    company_name  RAM  ROM                 type  height_in   display  \
# 0       SAMSUNG   12  512    Galaxy Z Fold4 5G        7.6  Full HD+
# 1       SAMSUNG   12  256    Galaxy Z Fold3 5G        7.6     QXGA+
# 2       SAMSUNG   12  256    Galaxy Z Fold4 5G        7.6  Full HD+
# 3       SAMSUNG   12  256    Galaxy Z Fold3 5G        7.6     QXGA+
# 4       SAMSUNG   12  512  Galaxy S22 Ultra 5G        6.8  Quad HD+
# 5       SAMSUNG   12  512  Galaxy S23 Ultra 5G        6.8  Quad HD+
# 8       SAMSUNG   12  256  Galaxy S23 Ultra 5G        6.8  Quad HD+
# 12      SAMSUNG   12  256  Galaxy S22 Ultra 5G        6.8  Quad HD+
# 13      SAMSUNG    8  512   Galaxy S23 Plus 5G        6.6  Full HD+
#
#     battery_power  front_camera back_camera  height_cm  \
# 0            4400          10.0          72     19.304
# 1            4400          10.0          36     19.304
# 2            4400          10.0          72     19.304
# 3            4400          10.0          36     19.304
# ...

# %%
# to delete a columns in dataset 
#del df['company_name']
df.head()
# Out:
#   company_name  RAM  ROM                 type  height_in   display  \
# 0      SAMSUNG   12  512    Galaxy Z Fold4 5G        7.6  Full HD+
# 1      SAMSUNG   12  256    Galaxy Z Fold3 5G        7.6     QXGA+
# 2      SAMSUNG   12  256    Galaxy Z Fold4 5G        7.6  Full HD+
# 3      SAMSUNG   12  256    Galaxy Z Fold3 5G        7.6     QXGA+
# 4      SAMSUNG   12  512  Galaxy S22 Ultra 5G        6.8  Quad HD+
#
#    battery_power  front_camera back_camera  height_cm  \
# 0           4400          10.0          72     19.304
# 1           4400          10.0          36     19.304
# 2           4400          10.0          72     19.304
# 3           4400          10.0          36     19.304
# 4           5000          40.0         130     17.272
#
#                            processor      price
# 0       Qualcomm Snapdragon 8+ Gen 1  ₹1,64,999
# 1  Qualcomm Snapdragon 888 Octa-Core  ₹1,61,000
# 2       Qualcomm Snapdragon 8+ Gen 1  ₹1,54,999
# ...

# %%
del df['type']

# %%
del df ['display']

# %%
del df ['processor']

# %%
df.head()
# Out:
#   company_name  RAM  ROM  height_in  battery_power  front_camera back_camera  \
# 0      SAMSUNG   12  512        7.6           4400          10.0          72
# 1      SAMSUNG   12  256        7.6           4400          10.0          36
# 2      SAMSUNG   12  256        7.6           4400          10.0          72
# 3      SAMSUNG   12  256        7.6           4400          10.0          36
# 4      SAMSUNG   12  512        6.8           5000          40.0         130
#
#    height_cm      price
# 0     19.304  ₹1,64,999
# 1     19.304  ₹1,61,000
# 2     19.304  ₹1,54,999
# 3     19.304  ₹1,49,999
# 4     17.272  ₹1,42,999

# %%
del df['price']

# %%
# del df['company_name']

# %%
# correlation fumcton

corr = df.corr()
corr
# Out:
#                     RAM       ROM  height_in  battery_power  front_camera  \
# RAM            1.000000  0.709243   0.484208       0.211640      0.201164
# ROM            0.709243  1.000000   0.453564       0.173477      0.104548
# height_in      0.484208  0.453564   1.000000       0.636303      0.207253
# battery_power  0.211640  0.173477   0.636303       1.000000      0.216703
# front_camera   0.201164  0.104548   0.207253       0.216703      1.000000
# back_camera    0.332404  0.362931   0.383643       0.288055      0.208414
# height_cm      0.476373  0.451762   1.000000       0.634011      0.200799
#
#                back_camera  height_cm
# RAM               0.332404   0.476373
# ROM               0.362931   0.451762
# height_in         0.383643   1.000000
# battery_power     0.288055   0.634011
# front_camera      0.208414   0.200799
# back_camera       1.000000   0.382318
# height_cm         0.382318   1.000000

# %%
df.size
# Out:
# 3766

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 538 entries, 0 to 795
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   RAM            538 non-null    int64
#  1   ROM            538 non-null    int64
#  2   height_in      538 non-null    float64
#  3   battery_power  538 non-null    int64
#  4   front_camera   537 non-null    float64
#  5   back_camera    537 non-null    object
#  6   height_cm      533 non-null    float64
# dtypes: float64(3), int64(3), object(1)
# memory usage: 33.6+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 12))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.1)
plt.title('Correlation Matrix')
plt.show()

# %%
# count plot


# Assuming df is your DataFrame and 'battery_power' is one of its columns
plt.figure(figsize=(12,12))

# Create a count plot for the 'battery_power' column
sns.countplot(data=df, x='battery_power')

# Set a title for the plot
plt.title('Count Plot for Battery Power')

# Show the plot
plt.show()

# %%
# corr

df[['battery_power','RAM']].corr()
# Out:
#                battery_power      RAM
# battery_power        1.00000  0.21164
# RAM                  0.21164  1.00000

# %%
# scatter plot 

plt.figure(figsize=(8,8))
sns.scatterplot(data=df,x='battery_power',y='RAM')
plt.title("price range vs RAM ")
plt.show()

# %%
### 1 . what is the distibution of front camera megapixel in the dataset

# %%
df.head()
# Out:
#    RAM  ROM  height_in  battery_power  front_camera back_camera  height_cm
# 0   12  512        7.6           4400          10.0          72     19.304
# 1   12  256        7.6           4400          10.0          36     19.304
# 2   12  256        7.6           4400          10.0          72     19.304
# 3   12  256        7.6           4400          10.0          36     19.304
# 4   12  512        6.8           5000          40.0         130     17.272

# %%
#creating histogram

plt.hist(df['front_camera'])
# Out:
# (array([230.,  50.,  64.,  23., 103.,  42.,   3.,   0.,   0.,  22.]),
#  array([  8.,  18.,  28.,  38.,  48.,  58.,  68.,  78.,  88.,  98., 108.]),
#  <BarContainer object of 10 artists>)

# %%
sns.histplot(df['front_camera'])
# Out:
# <Axes: xlabel='front_camera', ylabel='Count'>

# %%
## 2. how can you visualise the distribution of the ram fature in different rom?

# %%
df.columns
# Out:
# Index(['RAM', 'ROM', 'height_in', 'battery_power', 'front_camera',
#        'back_camera', 'height_cm'],
#       dtype='object')

# %%
plt.figsize = (6,10)
sns.boxplot(x= 'RAM',y= "ROM",data = df)
# Out:
# <Axes: xlabel='RAM', ylabel='ROM'>

# %%
## 3. can you create a pair plot for numerical columns to see  their pairwise relationship

# %%
sns.pairplot(df,vars=['battery_power','RAM','height_in'],hue = 'RAM')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.columns
# Out:
# Index(['RAM', 'ROM', 'height_in', 'battery_power', 'front_camera',
#        'back_camera', 'height_cm'],
#       dtype='object')

# %%
##4.what is the disrtibution of mobile height across different RAM

# %%
plt.figure(figsize=(10, 6))

# Assuming 'height_in' and 'RAM' are columns in your DataFrame (df)
sns.violinplot(x='height_in', y='RAM', data=df)

plt.show()

# %%
# 5. can you visualize the relationship betweeen battery power and ram with respect to the height

# %%
df.columns
# Out:
# Index(['RAM', 'ROM', 'height_in', 'battery_power', 'front_camera',
#        'back_camera', 'height_cm'],
#       dtype='object')

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='battery_power',y='RAM',data=df)
# Out:
# <Axes: xlabel='battery_power', ylabel='RAM'>

# %%
sns.scatterplot(x='battery_power', y= 'RAM',data=df , hue='height_cm')
# Out:
# <Axes: xlabel='battery_power', ylabel='RAM'>

# %%
# 6. can you visualize the count of mobiles with RAM and rom support using a pie chart

df['RAM'].unique()
# Out:
# array([12,  8,  4, 16,  6,  3], dtype=int64)

# %%
df['ROM'].unique()
# Out:
# array([512, 256, 128,  64,  32,  16], dtype=int64)

# %%
labels = ['RAM','ROM']
sizes =[df['RAM'].count(),df['ROM'].count()]
plt.pie(sizes,labels=labels,autopct='%1.1f%%')
plt.show()

# %%
labels = ['RAM','ROM']
sizes =[df['RAM'].sum(),df['ROM'].sum()]
plt.pie(sizes,labels=labels,autopct='%1.1f%%')
plt.show()

# %%
#7. what is the distribution of ram with rom

sns.boxplot(x='RAM',y='ROM',data=df)
# Out:
# <Axes: xlabel='RAM', ylabel='ROM'>

# %%
# 8. can you visualize the distribution of battery power eith ram or rom

sns.histplot(data=df,x="battery_power",hue='RAM',multiple='stack')
# Out:
# <Axes: xlabel='battery_power', ylabel='Count'>

# %%
# 9. what is the average battery power for each RAM category?


average_b = df.groupby('RAM')['battery_power'].mean()
average_b
# Out:
# RAM
# 3     2977.500000
# 4     4004.897959
# 6     4764.266667
# 8     4659.089219
# 12    4708.766667
# 16    4966.666667
# Name: battery_power, dtype: float64

# %%
sns.barplot(x=average_b.index,y=average_b.values)
# Out:
# <Axes: xlabel='RAM'>

# %%
average_b.index
# Out:
# Index([3, 4, 6, 8, 12, 16], dtype='int64', name='RAM')

# %%
average_b.values
# Out:
# array([2977.5       , 4004.89795918, 4764.26666667, 4659.08921933,
#        4708.76666667, 4966.66666667])

# %%
# 10. how does the battery_power disrtibution vary on the presence of RAM

sns.countplot(x='battery_power',data=df,hue='RAM')
# Out:
# <Axes: xlabel='battery_power', ylabel='count'>

# %%
# what is the average battery power for devices that have RAM 8GB

average_c= df.groupby('RAM')['battery_power'].mean()
average_c
# Out:
# RAM
# 3     2977.500000
# 4     4004.897959
# 6     4764.266667
# 8     4659.089219
# 12    4708.766667
# 16    4966.666667
# Name: battery_power, dtype: float64

# %%
sns.barplot(x=average_c.index,y=average_c.values)
# Out:
# <Axes: xlabel='RAM'>

# %%
for i in df.columns:
    plt.figure(figsize=(4,4))
    sns.scatterplot(data=df,x='battery_power',y='RAM')
    plt.title('battery power vs ram')
    plt.show()
